# %%
from __future__ import print_function

# %%
def gradient(x, alpha=1.0):
    return 4*alpha*x**3

# %%
x = 10
alpha = 1.0/(6*x**2)+0.003

ans = x
for i in range(100000):
    ans = ans - gradient(ans, alpha)
    if i % 1000 == 0:
        print(ans)
print(ans)
# Out:
# -8.66666666667
# 0.16317502735
# 0.115539537529
# 0.0943839520756
# 0.0817598751213
# 0.0731398712149
# 0.0667745039052
# 0.0618260611704
# 0.0578364670151
# 0.0545313337705
# 0.0517349553407
# 0.0493289137376
# 0.0472301035913
# 0.0453782528259
# 0.0437284421479
# 0.0422464171382
# 0.0409055389875
# 0.0396847373033
# 0.038567097699
# 0.037538863936
# 0.0365887180921
# 0.0357072516108
# 0.0348865701604
# 0.0341199940524
# 0.0334018280561
# 0.0327271823788
# 0.0320918318916
# 0.0314921043038
# 0.0309247905062
# 0.0303870720669
# 0.0298764621342
# 0.0293907569102
# 0.0289279955312
# 0.0284864266868
# 0.0280644806788
# 0.0276607459028
# 0.0272739489481
# 0.0269029376764
# 0.0265466667652
# 0.0262041853036
# 0.0258746261047
# 0.0255571964598
# 0.0252511701111
# 0.0249558802573
# 0.0246707134379
# 0.0243951041697
# 0.0241285302281
# 0.0238705084828
# 0.023620591214
# 0.0233783628439
# 0.0231434370295
# 0.0229154540702
# 0.0226940785917
# 0.0224789974701
# 0.02226991797
# 0.0220665660683
# ...
